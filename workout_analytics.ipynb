# %% [markdown]
# # Workout Tracker

# %% [markdown]
# ---
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ---
# ## Google Sheets id information

# %%
# the following comment is the reference link for the google sheet workbook
link = 'https://docs.google.com/spreadsheets/d/1R6hkcFkji0Pep06ki28gb0thi5GxzTzh1eLBPjDF8kA/edit?usp=sharing'

sheet_id = link[39:83] # sheet id (from after d/ to before /edit)
sheet_https = link[0:39]# https link (from httpe to /d/)

# %% [markdown]
# ---
# ## Functions

# %%
def g_sheet_puller(google_sheet_link,week):
    sheet_id = link[39:83]
    sheet_https = link[0:39]
    xls = pd.ExcelFile(f'{sheet_https}{sheet_id}/export?format=xlsx')
    df = pd.read_excel(xls, week, header = 0)
    return df

# %% [markdown]
# ---
# # Week of 1-5-2026

# %% [markdown]
# This week is the first week of tracking, therefore will not have any graphs being displayed.

# %%
week_of_1_5_26 = g_sheet_puller(link, '1_5_26')

# %%
week_of_1_5_26
# Out:
#           workout  set_1  set_2  set_3  set_4
# 0         zottman     10     10     10     10
# 1         barbell     10     10     10     10
# 2          hammer     10     10     10     10
# 3         workout  set_1  set_2  set_3  set_4
# 4       leg_lifts     10     10     10     10
# 5  shoulder_lifts     10     10     10     10
# 6         workout  set_1  set_2  set_3  set_4
# 7  shoulder_press     10     10     10     10
# 8      extentions     10     10     10     10
# 9       back_curl     10     10     10     10
